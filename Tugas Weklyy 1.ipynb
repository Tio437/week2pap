# %% [markdown]
# Hellow python

# %%
# try your first
print('hellow Tio Romble 4')
# Out:
# hellow Tio Romble 4

# %%
# Tri to display "Teknologi inforfmasi - Universitas tidar"
print(""universitas tidar"")
# Out:
#   File "<ipython-input-34-86c664b9d473>", line 2
#     print(""universitas tidar"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("romble 4 cakep")
# Out:
# romble 4 cakep

# %% [markdown]
# tanggal dan jam

# %%
# check the python version
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %% [markdown]
# heloo dan hay

# %%
# practice on writing commens
print('hello,python!') # this line prints a string
print('hi') # untuk print hi
# Out:
# hello,python!
# hi

# %% [markdown]
# weekly 1

# %%
print('Nama         :Tio Restu pambudi\n')
print('NPM          :2440506076\n')
print('ALAMAT       :Muntilan\n')
print('Tinggi Badan :165\n')
print('Berat Badan  :58\n')
# Out:
# Nama         :Tio Restu pambudi
#
# NPM          :2440506076
#
# ALAMAT       :Muntilan
#
# Tinggi Badan :165
#
# Berat Badan  :58

# %% [markdown]
# minggu 2

# %%
print('\033[1mUNIVERSITAS TIDAR\033[0m \n')
print('Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.\n')
print('\033[1mJURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI\033[0m \n')
print('Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:\n')
print('     1. Teknik Elektro \033[3mBachelor of Electrical Engineering\033[0m \n')
print('     2. Teknik Telekomunikasi\033[3mBachelor of Information Technology\033[0m \n')
print('     3. Teknik Elektro Industri\033[3mBachelor of Industrial Mechatronics Engineering\033[0m \n')
# Out:
# UNIVERSITAS TIDAR
#
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI
#
# Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:
#
#      1. Teknik Elektro Bachelor of Electrical Engineering
#
#      2. Teknik TelekomunikasiBachelor of Information Technology
#
#      3. Teknik Elektro IndustriBachelor of Industrial Mechatronics Engineering

# %%
print('" tio lagi baca alquran "')
# Out:
# " tio lagi baca alquran "

# %%
print('baris 1\n\033[1mbaris 2\033[0m\n\033[3mbaris 3\033[0m')
# Out:
# baris 1
# baris 2
# baris 3

# %%
print('baris 1\n\nbaris 2\nbaris 3')
# Out:
# baris 1
#
# baris 2
# baris 3
